# %%
import pandas as pd
import folium
import re
# import googlemaps
import ast
import time
import requests

# %%
import json

with open("gmaps_to_link_w_labels_3.json", "r") as file:
    gmaps_to_link = json.load(file)

# %%
name_cnt = 0
title_cnt = 0
# Add markers for each point in the dictionary
for link, info_list in gmaps_to_link.items():
    for info in info_list:
        # print(info['link'])
        try:
            if info['rest_name'] is not None:
                # print(info['rest_name'])
                name_cnt += 1
        except KeyError:
            # print(info["title"])
            title_cnt += 1
            
print(name_cnt)
print(title_cnt)
# Out:
# 708
# 0

# %%
def extract_lat_long_from_dynamic_url(short_url):
    try:
        response = requests.get(short_url)
        final_url = response.url
        print(final_url)
        # Regular expressions to find latitude and longitude in different formats
        pattern1 = r'@(-?\d+\.\d+),(-?\d+\.\d+)'
        pattern2 = r'%40(-?\d+\.\d+),(-?\d+\.\d+)'
        pattern3 = r'!3d(-?\d+\.\d+)!4d(-?\d+\.\d+)'
        # Search for the patterns in the URL
        match1 = re.search(pattern1, final_url)
        match2 = re.search(pattern2, final_url)
        match3 = re.search(pattern3, final_url)
        if match1:
            latitude = match1.group(1)
            longitude = match1.group(2)
            return latitude, longitude
        elif match2:
            latitude = match2.group(1)
            longitude = match2.group(2)
            return latitude, longitude
        elif match3:
            latitude = match3.group(1)
            longitude = match3.group(2)
            return latitude, longitude
        else:
            return None, None
    except requests.RequestException as e:
        print(f"Failed to fetch URL: {short_url}, error: {e}")
        return None, None

# %%
for link, info_list in gmaps_to_link.items():
    for info in info_list:
        print(link)
        try:
            # info['lat'], info['long'] = extract_lat_long_from_dynamic_url(info['link'])
            print(info['lat'],info['long'])
        except:
            info['lat'], info['long'] = extract_lat_long_from_dynamic_url(link)
            print(info['lat'],info['long'])
# Out:
# https://maps.app.goo.gl/2GtbNmjb64a73joK9
# https://www.google.com/maps/place/Puneri+Vade/@12.8920372,77.6468138,17z/data=!3m1!4b1!4m6!3m5!1s0x3bae110b458d13e3:0xb7d1d7140c7ba67f!8m2!3d12.8920372!4d77.6493887!16s%2Fg%2F11j57v39fx?entry=tts&g_ep=EgoyMDI0MDUyOS4wKgBIAVAD
# 12.8920372 77.6468138
# https://maps.app.goo.gl/2X6idFktNJv8D4CW8
# https://www.google.com/maps/place/Dhanyam+Cafe/@12.9241146,77.5753434,17z/data=!3m1!4b1!4m6!3m5!1s0x3bae156e467deccb:0xf74161d81b6c3c00!8m2!3d12.9241146!4d77.5779183!16s%2Fg%2F11vfb0gfq3?entry=tts&g_ep=EgoyMDI0MDUyOS4wKgBIAVAD
# 12.9241146 77.5753434
# https://maps.app.goo.gl/2X6idFktNJv8D4CW8
# https://www.google.com/maps/place/Dhanyam+Cafe/@12.9241146,77.5753434,17z/data=!3m1!4b1!4m6!3m5!1s0x3bae156e467deccb:0xf74161d81b6c3c00!8m2!3d12.9241146!4d77.5779183!16s%2Fg%2F11vfb0gfq3?entry=tts&g_ep=EgoyMDI0MDUyOS4wKgBIAVAD
# 12.9241146 77.5753434
# https://maps.app.goo.gl/wjg9HzcEmmcnD2Y96
# https://maps.app.goo.gl/LXvoGiHfuRv9zjB47
# nan nan
# https://maps.app.goo.gl/LXvoGiHfuRv9zjB47
# nan nan
# https://maps.app.goo.gl/3sKkHUEFtfT8ENzr7
# nan nan
# https://maps.app.goo.gl/3sKkHUEFtfT8ENzr7
# nan nan
# https://maps.app.goo.gl/3sKkHUEFtfT8ENzr7
# nan nan
# https://maps.app.goo.gl/mPbLcFErANKmEi5Q9
# nan nan
# https://maps.app.goo.gl/mPbLcFErANKmEi5Q9
# nan nan
# https://maps.app.goo.gl/W5QS7ysWPhD7QTpd8
# nan nan
# https://maps.app.goo.gl/W5QS7ysWPhD7QTpd8
# nan nan
# https://goo.gl/maps/LFd5HgUE37J76oPn8
# 12.9334849 77.6191395
# https://goo.gl/maps/DLEdQ8Y4fKB6zYzq7
# 12.9295757 77.5715902
# https://g.page/THITWC?share
# nan nan
# https://maps.app.goo.gl/P6nsuk2JZUWM7vms9
# nan nan
# https://maps.app.goo.gl/78BKZtkbZtb1mZRV9
# nan nan
# https://maps.app.goo.gl/rhEktWnTVXjprXKM7"
# nan nan
# https://goo.gl/maps/Mfcwwje694kJvdYeA
# nan nan
# https://maps.app.goo.gl/7Mra39VE7Jf7Rvj97
# nan nan
# https://goo.gl/maps/kMeR3b7ndNKoTPP87
# 11.6710482 78.1375403
# https://maps.app.goo.gl/ZtUjQh1P2AwqVfb98
# nan nan
# https://maps.app.goo.gl/yAVBZrdm1aWMV8VU8
# nan nan
# https://maps.app.goo.gl/4bEbeBGCpeupr5ZXA
# nan nan
# https://maps.app.goo.gl/6o9TV3oVJBrAym5z9
# nan nan
# https://maps.app.goo.gl/Qpb4QRnUeYVBwDnn9
# nan nan
# https://maps.app.goo.gl/NCSNEPUTF38z9euG9
# nan nan
# https://maps.app.goo.gl/44crqhUcfLi9AZnU8
# nan nan
# https://maps.app.goo.gl/GF1UawDxiLD58dfi9
# nan nan
# https://maps.app.goo.gl/TPk5kCu2VQJGRu1T9
# nan nan
# https://maps.app.goo.gl/2fFeNiangGP3sKZM7
# nan nan
# https://maps.app.goo.gl/8qrPxCSKGLnQ49ez5
# nan nan
# https://maps.app.goo.gl/xYu1k
# nan nan

# %%
from folium.plugins import Geocoder
from folium.plugins import LocateControl
m = folium.Map(location=[12.9, 77.5], zoom_start=7, tiles='https://server.arcgisonline.com/ArcGIS/rest/services/World_Street_Map/MapServer/tile/{z}/{y}/{x}', attr='Esri')
Geocoder().add_to(m)
# Add markers for each point in the dictionary
for link, info_list in gmaps_to_link.items():
    for info in info_list:
        if not pd.isnull(info["lat"]) and not pd.isnull(info["long"]):
            popup_content = f"<b>{info['rest_name']}</b><br>"
            if 'link' in info:
                popup_content += f"YouTube: <a href='{info['link']}' target='_blank'><i class='fab fa-youtube'></i></a><br>"
            if 'address' in info:
                popup_content += f"Address: {info['address']} <br> <a href={link} target='_blank'><i class='fa-solid fa-map'></i></a><br>"
            if 'cuisine' in info:
                popup_content += f"Cuisine: {info['cuisine']}<br>"
            if 'v_n_ng' in info:
                popup_content += f"Veg/Non-Veg: {info['v_n_ng']}<br>"
                
            folium.Marker(
                location=[info["lat"], info["long"]],
                popup=folium.Popup(popup_content,max_width='100%'),
                tooltip=info["rest_name"]
            ).add_to(m)
            
LocateControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_19d9985791a572eff26a8f945ad238ed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-locatecontrol/0.66.2/L.Control.Locate.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-locatecontrol/0.66.2/L.Control.Locate.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_19d9985791a572eff26a8f945ad238ed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_19d9985791a572eff26a8f945ad238ed = L.map(
#                 &quot;map_19d9985791a572eff26a8f945ad238ed&quot;,
#                 {
#                     center: [12.9, 77.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_62b4e2080304ddf1a07468db06768b1d = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Street_Map/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Esri&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_62b4e2080304ddf1a07468db06768b1d.addTo(map_19d9985791a572eff26a8f945ad238ed);
#
#
#
#             var geocoderOpts_geocoder_ba957f4189cd212bcba9016eb811df09 = {&quot;collapsed&quot;: false, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topright&quot;, &quot;provider&quot;: &quot;nominatim&quot;, &quot;providerOptions&quot;: {}, &quot;zoom&quot;: 11};
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_ba957f4189cd212bcba9016eb811df09 = geocoderOpts_geocoder_ba957f4189cd212bcba9016eb811df09[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_ba957f4189cd212bcba9016eb811df09 = L.Control.Geocoder[ geocoderName_geocoder_ba957f4189cd212bcba9016eb811df09 ](
#                 geocoderOpts_geocoder_ba957f4189cd212bcba9016eb811df09[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_ba957f4189cd212bcba9016eb811df09[&quot;geocoder&quot;] = customGeocoder_geocoder_ba957f4189cd212bcba9016eb811df09;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_ba957f4189cd212bcba9016eb811df09
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_ba957f4189cd212bcba9016eb811df09[&#x27;zoom&#x27;] || map_19d9985791a572eff26a8f945ad238ed.getZoom();
#                 map_19d9985791a572eff26a8f945ad238ed.setView(e.geocode.center, zoom);
#             }).addTo(map_19d9985791a572eff26a8f945ad238ed);
#
#
#
#             var marker_9f3725a5b448e17009fea60512720503 = L.marker(
#                 [12.8920372, 77.6468138],
#                 {}
#             ).addTo(map_19d9985791a572eff26a8f945ad238ed);
#
#
#         var popup_853f996c760c7a929746dbfaf0cf222c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_31b77e7ec2a5fdf9e7bce3adfde14ef5 = $(`&lt;div id=&quot;html_31b77e7ec2a5fdf9e7bce3adfde14ef5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Puneri Vade&lt;/b&gt;&lt;br&gt;YouTube: &lt;a href=&#x27;https://www.youtube.com/watch?v=IQoVOqwPZZA&#x27; target=&#x27;_blank&#x27;&gt;&lt;i class=&#x27;fab fa-youtube&#x27;&gt;&lt;/i&gt;&lt;/a&gt;&lt;br&gt;Address: 383, Kudlu Rd, Hosapalaya, Muneshwara Nagar, Bengaluru, Karnataka 560068 &lt;br&gt; &lt;a href=https://maps.app.goo.gl/2GtbNmjb64a73joK9 target=&#x27;_blank&#x27;&gt;&lt;i class=&#x27;fa-solid fa-map&#x27;&gt;&lt;/i&gt;&lt;/a&gt;&lt;br&gt;Cuisine: [&#x27;Maharashtrian&#x27;, &#x27;Street Food&#x27;]&lt;br&gt;Veg/Non-Veg: Veg&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_853f996c760c7a929746dbfaf0cf222c.setContent(html_31b77e7ec2a5fdf9e7bce3adfde14ef5);
#
#
#
#         marker_9f3725a5b448e17009fea60512720503.bindPopup(popup_853f996c760c7a929746dbfaf0cf222c)
#         ;
#
#
#
#
#             marker_9f3725a5b448e17009fea60512720503.bindTooltip(
#                 `&lt;div&gt;
#                      Puneri Vade
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6759f39c94bfbabbef98bfb88d082f3f = L.marker(
#                 [12.9241146, 77.5753434],
#                 {}
#             ).addTo(map_19d9985791a572eff26a8f945ad238ed);
#
#
#         var popup_68804ac8d0366e357f2ba1819c21956d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d
#   'transcription': 'Error: \nCould not retrieve a transcript for the video https://www.youtube.com/watch?v=idx6j5ZPSko! This is most likely caused by:\n\nSubtitles are disabled for this video\n\nIf you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!',
#   'lat': nan,
#   'long': nan,
#   'rest_name': 'Diggi Palace Kitchen',
#   'address': 'Diggi House, Shivaji Marg, Sawai Ram Singh Rd, C Scheme, Jaipur, Rajasthan 302004',
#   'ph_no': '+91 0141 237 3091',
#   'cuisine': ['Indian', 'Street Food', 'Rajasthani'],
#   'price': '$',
#   'v_n_ng': 'Veg',
#   'best_dishes': [{'name': 'Aloo Tikki',
#     'summary': 'A popular Indian street food dish consisting of a crispy potato patty served with chutney.',
#     'price': 'Rs. 45 - 75'},
#    {'name': 'Pyaaz Kachori',
#     'summary': 'A crispy, deep-fried pastry filled with a spicy onion filling.',
#     'price': 'Rs. 45 - 75'},
#    {'name': 'Dal Kachori',
#     'summary': 'A crispy, deep-fried pastry filled with a spiced lentil filling.',
#     'price': 'Rs. 45 - 75'},
#    {'name': 'Gond Ke Ladoo',
#     'summary': 'Sweet and nutty ladoos made with edible gum, nuts, and jaggery.',
#     'price': 'Rs. 45 - 75'},
#    {'name': 'Kulhad Chai',
#     'summary': 'Traditional Indian tea served in earthen clay cups.',
#     'price': 'Rs. 45 - 75'}],
#   'summary': 'The Diggi Palace Kitchen sets up a pop-up chaat and chai shop during the Jaipur Literature Festival, offering authentic local dishes. The highlight of this eatery is its simple yet flavorful menu featuring dishes like aloo tikki, kachori, gond ke ladoo, and kulhad chai. This spot is popular among the festival attendees.'}]

# %%
vnng = []
for link, info_list in gmaps_to_link.items():
    for info in info_list:
        if not pd.isnull(info["lat"]) and not pd.isnull(info["long"]):
            # print(info["rest_name"])
            category = str(info.get('v_n_ng'))
            # print(category)
            vnng.append(category)

# %%
set(vnng)
# Out:
# {'Non-veg', 'Unknown', 'Veg'}

# %%
def map_to_veg_nonveg(category):
    non_veg_indicators = ['Non-veg', "['Non-veg', 'Veg']", "['Non-veg']", "['Veg', 'Non-veg']"]
    veg_indicators = ['Veg', 'Vegetarian', "['Veg']"]
    
    if any(indicator in category for indicator in non_veg_indicators):
        return 'Non-veg'
    elif any(indicator in category for indicator in veg_indicators):
        return 'Veg'
    else:
        return 'Non-veg'  # Handle unexpected or missing values

# Iterate over the dictionary and update the 'v_n_ng' value
for link, info_list in gmaps_to_link.items():
    for info in info_list:
        if not pd.isnull(info["lat"]) and not pd.isnull(info["long"]):
            category = str(info.get('v_n_ng'))
            mapped_category = map_to_veg_nonveg(category)
            info['v_n_ng'] = mapped_category

# %%
m = folium.Map(location=[12.9, 77.5], zoom_start=7, tiles='https://server.arcgisonline.com/ArcGIS/rest/services/World_Street_Map/MapServer/tile/{z}/{y}/{x}', attr='Esri')

# Initialize the dictionary of feature groups based on veg/non-veg/other type
category_groups = {}
Geocoder(position = 'topright').add_to(m)
for link, info_list in gmaps_to_link.items():
    for info in info_list:
        if not pd.isnull(info["lat"]) and not pd.isnull(info["long"]) :
            popup_content = f"<b>{info['rest_name']}</b><br>"
            if 'link' in info:
                popup_content += f"YouTube: <a href='{info['link']}' target='_blank'><i class='fab fa-youtube'></i></a><br>"
            if 'address' in info:
                popup_content += f"Address: {info['address']} <a href='{link}' target='_blank'><i class='fa-solid fa-map'></i></a>"

            # Determine the veg/non-veg/other type and add to the appropriate feature group
            category = str(info.get('v_n_ng'))
            # price = info.get('price', 'Not sure')
            if category not in category_groups:
                category_groups[category] = folium.FeatureGroup(name=category)
                
            
            folium.Marker(
                location=[info["lat"], info["long"]],
                popup=folium.Popup(popup_content, max_width='50%'),
                tooltip=info["rest_name"]
            ).add_to(category_groups[category])

# Add all feature groups to the map
for category, group in category_groups.items():
    group.add_to(m)

# Add a layer control to the map
folium.LayerControl().add_to(m)

LocateControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_47c116bf3df290e6792486066c7d6c16 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-locatecontrol/0.66.2/L.Control.Locate.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-locatecontrol/0.66.2/L.Control.Locate.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_47c116bf3df290e6792486066c7d6c16&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_47c116bf3df290e6792486066c7d6c16 = L.map(
#                 &quot;map_47c116bf3df290e6792486066c7d6c16&quot;,
#                 {
#                     center: [12.9, 77.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_081b6f7092b45c257452cdf581fe8497 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Street_Map/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Esri&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_081b6f7092b45c257452cdf581fe8497.addTo(map_47c116bf3df290e6792486066c7d6c16);
#
#
#
#             var geocoderOpts_geocoder_46f637469e292573b356a84a3937ea39 = {&quot;collapsed&quot;: false, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topright&quot;, &quot;provider&quot;: &quot;nominatim&quot;, &quot;providerOptions&quot;: {}, &quot;zoom&quot;: 11};
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_46f637469e292573b356a84a3937ea39 = geocoderOpts_geocoder_46f637469e292573b356a84a3937ea39[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_46f637469e292573b356a84a3937ea39 = L.Control.Geocoder[ geocoderName_geocoder_46f637469e292573b356a84a3937ea39 ](
#                 geocoderOpts_geocoder_46f637469e292573b356a84a3937ea39[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_46f637469e292573b356a84a3937ea39[&quot;geocoder&quot;] = customGeocoder_geocoder_46f637469e292573b356a84a3937ea39;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_46f637469e292573b356a84a3937ea39
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_46f637469e292573b356a84a3937ea39[&#x27;zoom&#x27;] || map_47c116bf3df290e6792486066c7d6c16.getZoom();
#                 map_47c116bf3df290e6792486066c7d6c16.setView(e.geocode.center, zoom);
#             }).addTo(map_47c116bf3df290e6792486066c7d6c16);
#
#
#
#             var feature_group_164c6694f75bb89fc74ffe976a144f96 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_a369d50381528a25b06f490c72baafe9 = L.marker(
#                 [12.8920372, 77.6468138],
#                 {}
#             ).addTo(feature_group_164c6694f75bb89fc74ffe976a144f96);
#
#
#         var popup_b428b4749b9194c454ea3c7c41871802 = L.popup({&quot;maxWidth&quot;: &quot;50%&quot;});
#
#
#
#                 var html_5d583e53988f63ebcad7f1de1467f985 = $(`&lt;div id=&quot;html_5d583e53988f63ebcad7f1de1467f985&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Puneri Vade&lt;/b&gt;&lt;br&gt;YouTube: &lt;a href=&#x27;https://www.youtube.com/watch?v=IQoVOqwPZZA&#x27; target=&#x27;_blank&#x27;&gt;&lt;i class=&#x27;fab fa-youtube&#x27;&gt;&lt;/i&gt;&lt;/a&gt;&lt;br&gt;Address: 383, Kudlu Rd, Hosapalaya, Muneshwara Nagar, Bengaluru, Karnataka 560068 &lt;a href=&#x27;https://maps.app.goo.gl/2GtbNmjb64a73joK9&#x27; target=&#x27;_blank&#x27;&gt;&lt;i class=&#x27;fa-solid fa-map&#x27;&gt;&lt;/i&gt;&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_b428b4749b9194c454ea3c7c41871802.setContent(html_5d583e53988f63ebcad7f1de1467f985);
#
#
#
#         marker_a369d50381528a25b06f490c72baafe9.bindPopup(popup_b428b4749b9194c454ea3c7c41871802)
#         ;
#
#
#
#
#             marker_a369d50381528a25b06f490c72baafe9.bindTooltip(
#                 `&lt;div&gt;
#                      Puneri Vade
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0fbdd99d7dd09927f8cebee62a35bdae = L.marker(
#                 [12.9241146, 77.5753434],
#                 {}
#             ).addTo(feature_group_164c6694f75bb89fc74ffe976a144f96);
#
#
#         var popup_1012059aa383b7bceabd0d6e8fdbd220 = L.popup({&quot;maxWidth&quot;: &quot;50%&quot;});
#
#
#
#                 var html_fb1107660c9490c08ee48059817c90dc = $(`&lt;div id=&quot;html_fb1107660c9490c08ee48059817c90dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Dhanyam Café&lt;/b&gt;&lt;br&gt;YouTube: &lt;a href=&#x27;https://www.youtube.com/watch?v=soAOqI-dCmM&#x27; target=&#x27;_blank&#x27;&gt;&lt;i class=&#x27;fab fa-youtube&#x27;&gt;&lt;/i&gt;

# %%
m.save("Website/youtube_map_4.html")

# %%
m = folium.Map(location=[12.9, 77.5], zoom_start=7, tiles='https://server.arcgisonline.com/ArcGIS/rest/services/World_Street_Map/MapServer/tile/{z}/{y}/{x}', attr='Esri')

# Initialize the list of all markers for tag filtering
all_markers = []

# Iterate through the dictionary and create markers
for link, info_list in gmaps_to_link.items():
    for info in info_list:
        if not pd.isnull(info["lat"]) and not pd.isnull(info["long"]):
            popup_content = f"<b>{info['rest_name']}</b><br>"
            if 'link' in info:
                popup_content += f"YouTube: <a href='{info['link']}' target='_blank'><i class='fab fa-youtube'></i></a><br>"
            if 'address' in info:
                popup_content += f"Address: {info['address']} <a href='{link}' target='_blank'><i class='fa fa-map-marker'></i></a>"

            # Determine the veg/non-veg/other type and use it as a tag
            category = str(info.get('v_n_ng'))
            # price = info.get('price', 'Not sure')

            # Create the marker with tags
            marker = folium.Marker(
                location=[info["lat"], info["long"]],
                popup=folium.Popup(popup_content, max_width='50%'),
                tooltip=info["rest_name"]
            )
            marker.add_child(folium.Popup(f'Category: {category}<br>Price: {price}'))
            marker.add_child(folium.Tooltip(info["rest_name"]))
            all_markers.append((marker, [category]))

# Add all markers to the map
for marker, tags in all_markers:
    marker.add_to(m)

# Add the TagFilterButton
TagFilterButton(data=["Veg","Non-veg"]).add_to(m)

# Add a layer control to the map
folium.LayerControl().add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b20df1945cdb414c346ad9f823129e50 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-tag-filter-button/src/leaflet-tag-filter-button.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-easybutton@2/src/easy-button.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-tag-filter-button/src/leaflet-tag-filter-button.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-easybutton@2/src/easy-button.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/css-ripple-effect@1.0.5/dist/ripple.min.css&quot;/&gt;
#
#             &lt;style&gt;
#                 .easy-button-button {
#                   display: block !important;
#                 }
#
#                 .tag-filter-tags-container {
#                   left: 30px;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b20df1945cdb414c346ad9f823129e50&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b20df1945cdb414c346ad9f823129e50 = L.map(
#                 &quot;map_b20df1945cdb414c346ad9f823129e50&quot;,
#                 {
#                     center: [12.9, 77.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_711cb82062cb6d95f656681b0e696eb2 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Street_Map/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Esri&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_711cb82062cb6d95f656681b0e696eb2.addTo(map_b20df1945cdb414c346ad9f823129e50);
#
#
#             var marker_5387b0e006a6c7bbec3d270360b6e1f4 = L.marker(
#                 [12.8920372, 77.6468138],
#                 {}
#             ).addTo(map_b20df1945cdb414c346ad9f823129e50);
#
#
#         var popup_1d34d3ac8a5fd546980b0e65e14694c8 = L.popup({&quot;maxWidth&quot;: &quot;50%&quot;});
#
#
#
#                 var html_5dc72b93eaf88848c1d0f09e92bcf1f2 = $(`&lt;div id=&quot;html_5dc72b93eaf88848c1d0f09e92bcf1f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Puneri Vade&lt;/b&gt;&lt;br&gt;YouTube: &lt;a href=&#x27;https://www.youtube.com/watch?v=IQoVOqwPZZA&#x27; target=&#x27;_blank&#x27;&gt;&lt;i class=&#x27;fab fa-youtube&#x27;&gt;&lt;/i&gt;&lt;/a&gt;&lt;br&gt;Address: 383, Kudlu Rd, Hosapalaya, Muneshwara Nagar, Bengaluru, Karnataka 560068 &lt;a href=&#x27;https://maps.app.goo.gl/2GtbNmjb64a73joK9&#x27; target=&#x27;_blank&#x27;&gt;&lt;i class=&#x27;fa fa-map-marker&#x27;&gt;&lt;/i&gt;&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_1d34d3ac8a5fd546980b0e65e14694c8.setContent(html_5dc72b93eaf88848c1d0f09e92bcf1f2);
#
#
#
#         marker_5387b0e006a6c7bbec3d270360b6e1f4.bindPopup(popup_1d34d3ac8a5fd546980b0e65e14694c8)
#         ;
#
#
#
#
#             marker_5387b0e006a6c7bbec3d270360b6e1f4.bindTooltip(
#                 `&lt;div&gt;
#                      Puneri Vade
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#         var popup_d1583671c03898e80a4971c72eddb180 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d8c666bf1735a1230c4aec476df551b6 = $(`&lt;div id=&quot;html_d8c666bf1735a1230c4aec476df551b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Category: Veg&lt;br&gt;Price: $$&lt;/div&gt;`)[0];
#                 popup_d1583671c03898e80a4971c72eddb180.setContent(html_d8c666bf1735a1230c4aec476df551b6);
#
#
#
#         marker_5387b0e006a6c7bbec3d270360b6e1f4.bindPopup(popup_d1583671c03898e80a4971c72eddb180)
#         ;
#
#
#
#
#             marker_5387b0e006a6c7bbec3d270360b6e1f4.bindTooltip(
#                 `&lt;div&gt;
#                      Puneri Vade
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_75379a704df65f86bf9ae49e1e583ff6 = L.marker(
#                 [12.9241146, 77.5753434],
#                 {}
#             ).addTo(map_b20df1945cdb414c346ad9f823129e50);
#
#
#         var popup_e228f21bf8a6e2378b7aa2c9b920373a = L.popup({&quot;maxWidth&quot;: &quot;50%&quot;});
#
#
#
#                 var html_7b2321afa612f8bce12fbddb62bde198 = $(`&lt;div id=&quot;html_7b2321afa612f8bce12fbddb62bde198&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Dhanyam Café&lt;/b&gt;&lt;br&gt;YouTube: &lt;a href=&#x27;https://www.youtube.com/watch?v=soAOqI-dCmM&#x27; target=&#x27;_blank&#x27;&gt;&lt;i class=&#x27;fab fa-youtube&#x27;&gt;&lt;/i&gt;&lt;/a&gt;&lt;br&gt;Address: 78A, 36th &#x27;A&#x27; cross, 2nd Main Rd, 7th Block, Jayanagar, Bengaluru, Karnataka 560070 &lt;a href=&#x27;https://maps.app.goo.gl/2X6idFktNJv8D4CW8&#x27; target=&#x27;_blank&#x27;&gt;&lt;i class=&#x27;fa fa-map-marker&#x27;&gt;&lt;/i&gt;&lt;/a&gt;&lt;/div&gt;`)[0];

# %%
from langchain_community.document_loaders import JSONLoader
import json
from pathlib import Path
from pprint import pprint

# %%
file_path = Path("gmaps_to_link_w_labels_3.json")
data = json.load(open(file_path))
